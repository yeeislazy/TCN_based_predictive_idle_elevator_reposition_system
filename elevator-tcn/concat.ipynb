# %%
import pandas as pd
from torch.utils.tensorboard import SummaryWriter
import os

# %%
current_dir = os.getcwd()

read_path = ['models_v'+ str(i) for i in range(1,4)]

# %%
model_df1 = pd.read_csv(os.path.join(current_dir, read_path[0], 'model_df.csv'))
model_df1
# Out:
#                                                  Model  weight  epoch  \
# 0    weight_0_epoch00_acc0.9323_prec0.7434_rec0.186...     0.0      0
# 1    weight_0_epoch01_acc0.9324_prec0.7172_rec0.203...     0.0      1
# 2    weight_0_epoch02_acc0.9323_prec0.7249_rec0.196...     0.0      2
# 3    weight_0_epoch03_acc0.9321_prec0.7118_rec0.200...     0.0      3
# 4    weight_0_epoch04_acc0.9319_prec0.7253_rec0.188...     0.0      4
# ..                                                 ...     ...    ...
# 245  weight_1_epoch45_acc0.7356_prec0.1965_rec0.786...     1.0     45
# 246  weight_1_epoch46_acc0.7357_prec0.1963_rec0.784...     1.0     46
# 247  weight_1_epoch47_acc0.7388_prec0.1978_rec0.781...     1.0     47
# 248  weight_1_epoch48_acc0.7381_prec0.1976_rec0.783...     1.0     48
# 249  weight_1_epoch49_acc0.7371_prec0.1972_rec0.784...     1.0     49
#
#           acc  precision    recall
# 0    0.932304   0.743420  0.186212
# 1    0.932412   0.717181  0.203667
# 2    0.932303   0.724914  0.196505
# 3    0.932118   0.711849  0.200818
# 4    0.931943   0.725334  0.188720
# ..        ...        ...       ...
# 245  0.735648   0.196527  0.786434
# 246  0.735666   0.196279  0.784732
# 247  0.738818   0.197835  0.781623
# 248  0.738106   0.197638  0.783371
# 249  0.737123   0.197150  0.784324
#
# [250 rows x 6 columns]

# %%
model1= 'norestart_noweightclamp'
weights = list(model_df1['weight'].unique())
for weight in weights:
    run_dir =os.path.join(current_dir,'runs', model1 + f'_weight_{weight}')
    os.makedirs(run_dir, exist_ok=True)
    writer = SummaryWriter(log_dir=run_dir)
    df_weight = model_df1[model_df1['weight'] == weight]
    for index, row in df_weight.iterrows():
        epoch = row['epoch']
        val_acc = row['acc']
        val_precision = row['precision']
        val_recall = row['recall']
        writer.add_scalar('Acc/val', val_acc, epoch)
        writer.add_scalar('Precision/val', val_precision, epoch)
        writer.add_scalar('Recall/val', val_recall, epoch)
            
    writer.close()

# %%
model_df2 = pd.read_csv(os.path.join(current_dir, read_path[1], 'model_df.csv'))
model_df2
# Out:
#                                                  Model  weight  epoch  \
# 0    weight_0_epoch00_acc0.9323_prec0.7336_rec0.191...     0.0      0
# 1    weight_0_epoch01_acc0.9324_prec0.7172_rec0.203...     0.0      1
# 2    weight_0_epoch02_acc0.9324_prec0.7377_rec0.191...     0.0      2
# 3    weight_0_epoch03_acc0.9323_prec0.7363_rec0.189...     0.0      3
# 4    weight_0_epoch04_acc0.9324_prec0.7367_rec0.190...     0.0      4
# ..                                                 ...     ...    ...
# 245  weight_1_epoch45_acc0.7431_prec0.1993_rec0.773...     1.0     45
# 246  weight_1_epoch46_acc0.7393_prec0.1981_rec0.781...     1.0     46
# 247  weight_1_epoch47_acc0.7414_prec0.1986_rec0.775...     1.0     47
# 248  weight_1_epoch48_acc0.7413_prec0.1988_rec0.777...     1.0     48
# 249  weight_1_epoch49_acc0.7422_prec0.1991_rec0.775...     1.0     49
#
#           acc  precision    recall
# 0    0.932316   0.733645  0.191697
# 1    0.932418   0.717174  0.203800
# 2    0.932437   0.737656  0.191927
# 3    0.932279   0.736264  0.189512
# 4    0.932357   0.736697  0.190838
# ..        ...        ...       ...
# 245  0.743053   0.199337  0.773373
# 246  0.739264   0.198118  0.781649
# 247  0.741406   0.198556  0.775378
# 248  0.741288   0.198761  0.777195
# 249  0.742159   0.199127  0.775850
#
# [250 rows x 6 columns]

# %%
model2= 'restart_noweightclamp'
weights = list(model_df2['weight'].unique())
for weight in weights:
    run_dir =os.path.join(current_dir,'runs', model2 + f'_weight_{weight}')
    os.makedirs(run_dir, exist_ok=True)
    writer = SummaryWriter(log_dir=run_dir)
    df_weight = model_df2[model_df2['weight'] == weight]
    for index, row in df_weight.iterrows():
        epoch = row['epoch']
        val_acc = row['acc']
        val_precision = row['precision']
        val_recall = row['recall']
        writer.add_scalar('Acc/val', val_acc, epoch)
        writer.add_scalar('Precision/val', val_precision, epoch)
        writer.add_scalar('Recall/val', val_recall, epoch)
            
    writer.close()

# %%
model_df3 = pd.read_csv(os.path.join(current_dir, read_path[2], 'model_df.csv'))
model_df3
# Out:
#                                                  Model  weight  epoch  \
# 0    weight_1_epoch00_acc0.9324_prec0.7467_rec0.185...       1      0
# 1    weight_1_epoch01_acc0.9324_prec0.7389_rec0.190...       1      1
# 2    weight_1_epoch02_acc0.9324_prec0.7400_rec0.190...       1      2
# 3    weight_1_epoch03_acc0.9322_prec0.7239_rec0.194...       1      3
# 4    weight_1_epoch04_acc0.9322_prec0.7234_rec0.195...       1      4
# ..                                                 ...     ...    ...
# 245  weight_100_epoch45_acc0.8910_prec0.3305_rec0.4...     100     45
# 246  weight_100_epoch46_acc0.8885_prec0.3277_rec0.4...     100     46
# 247  weight_100_epoch47_acc0.8877_prec0.3229_rec0.4...     100     47
# 248  weight_100_epoch48_acc0.8885_prec0.3261_rec0.4...     100     48
# 249  weight_100_epoch49_acc0.8871_prec0.3232_rec0.4...     100     49
#
#           acc  precision    recall
# 0    0.932374   0.746703  0.185926
# 1    0.932416   0.738918  0.190827
# 2    0.932429   0.740035  0.190488
# 3    0.932197   0.723910  0.194888
# 4    0.932225   0.723367  0.195809
# ..        ...        ...       ...
# 245  0.890973   0.330476  0.403780
# 246  0.888490   0.327749  0.424686
# 247  0.887663   0.322890  0.416733
# 248  0.888534   0.326130  0.418155
# 249  0.887073   0.323207  0.424872
#
# [250 rows x 6 columns]

# %%
model3= 'restart_logitsclamp_weightclamp'
weights = list(model_df3['weight'].unique())
for weight in weights:
    run_dir =os.path.join(current_dir,'runs', model3 + f'_weight_{weight}')
    os.makedirs(run_dir, exist_ok=True)
    writer = SummaryWriter(log_dir=run_dir)
    df_weight = model_df3[model_df3['weight'] == weight]
    for index, row in df_weight.iterrows():
        epoch = row['epoch']
        val_acc = row['acc']
        val_precision = row['precision']
        val_recall = row['recall']
        writer.add_scalar('Acc/val', val_acc, epoch)
        writer.add_scalar('Precision/val', val_precision, epoch)
        writer.add_scalar('Recall/val', val_recall, epoch)
            
    writer.close()

# %%
model_names = []
for dir in os.listdir(os.path.join(current_dir)):
    dir = str(dir)
    if dir.endswith('.ipynb') and dir != 'concat.ipynb' and dir != 'model_eval.ipynb':
        model_names.append(dir.replace('.ipynb',''))
model_names
# Out:
# ['model_training-v1_norestart_noweightclamp',
#  'model_training-v2_restart_noweightclamp',
#  'model_training-v3_restart_logitsclamp_weightclamp',
#  'model_training-v4_restart_thresholdsearch',
#  'model_training-v5_restart_focalloss',
#  'model_training-v6_restart_thresholdsearch_focalloss']

# %%
model_dirs = ['models_v'+ str(i) for i in range(1,7)]
model_sum_df = pd.DataFrame(columns= ['model_name','model_with_parameter' ,'weight', 'epoch','alpha', 'acc', 'precision', 'recall', 'path'])
for i , model_dir in enumerate(model_dirs):
    model_df = pd.read_csv(os.path.join(current_dir, model_dir, 'model_df.csv'))
    model_name = model_names[i]
    for index, row in model_df.iterrows():
        where_epoch = row['Model'].find('_epoch')
        parameter = row['Model'][0:where_epoch]
        model_with_parameter = model_name + '_' + parameter
        if 'weight' in row:
            weight = row['weight']
        else:
            weight = 'None'
        if 'alpha' in row:
            alpha = row['alpha']
        else:
            alpha = 'None'
        path = os.path.join(model_dir, row['Model'])
        model_sum_df.loc[len(model_sum_df)] = [model_name, model_with_parameter,weight, row['epoch'], alpha, row['acc'], row['precision'], row['recall'], path]
model_sum_df
# Out:
#                                              model_name  \
# 0             model_training-v1_norestart_noweightclamp
# 1             model_training-v1_norestart_noweightclamp
# 2             model_training-v1_norestart_noweightclamp
# 3             model_training-v1_norestart_noweightclamp
# 4             model_training-v1_norestart_noweightclamp
# ...                                                 ...
# 1395  model_training-v6_restart_thresholdsearch_foca...
# 1396  model_training-v6_restart_thresholdsearch_foca...
# 1397  model_training-v6_restart_thresholdsearch_foca...
# 1398  model_training-v6_restart_thresholdsearch_foca...
# 1399  model_training-v6_restart_thresholdsearch_foca...
#
#                                    model_with_parameter weight  epoch alpha  \
# 0     model_training-v1_norestart_noweightclamp_weig...    0.0      0  None
# 1     model_training-v1_norestart_noweightclamp_weig...    0.0      1  None
# 2     model_training-v1_norestart_noweightclamp_weig...    0.0      2  None
# 3     model_training-v1_norestart_noweightclamp_weig...    0.0      3  None
# 4     model_training-v1_norestart_noweightclamp_weig...    0.0      4  None
# ...                                                 ...    ...    ...   ...
# 1395  model_training-v6_restart_thresholdsearch_foca...   None     45  0.75
# 1396  model_training-v6_restart_thresholdsearch_foca...   None     46  0.75
# 1397  model_training-v6_restart_thresholdsearch_foca...   None     47  0.75
# 1398  model_training-v6_restart_thresholdsearch_foca...   None     48  0.75
# 1399  model_training-v6_restart_thresholdsearch_foca...   None     49  0.75
#
#            acc  precision    recall  \
# 0     0.932304   0.743420  0.186212
# 1     0.932412   0.717181  0.203667
# 2     0.932303   0.724914  0.196505
# 3     0.932118   0.711849  0.200818
# 4     0.931943   0.725334  0.188720
# ...        ...        ...       ...
# 1395  0.874173   0.164541  0.261330
# 1396  0.872900   0.164482  0.265458
# 1397  0.873962   0.164605  0.262311
# 1398  0.874147   0.164457  0.261036
# 1399  0.872953   0.164428  0.265296
#
#                                                    path
# 0     models_v1\weight_0_epoch00_acc0.9323_prec0.743...
# 1     models_v1\weight_0_epoch01_acc0.9324_prec0.717...
# 2     models_v1\weight_0_epoch02_acc0.9323_prec0.724...
# 3     models_v1\weight_0_epoch03_acc0.9321_prec0.711...
# 4     models_v1\weight_0_epoch04_acc0.9319_prec0.725...
# ...                                                 ...
# 1395  models_v6\alpha_0.75_epoch45_acc0.8742_prec0.1...
# 1396  models_v6\alpha_0.75_epoch46_acc0.8729_prec0.1...
# 1397  models_v6\alpha_0.75_epoch47_acc0.8740_prec0.1...
# 1398  models_v6\alpha_0.75_epoch48_acc0.8741_prec0.1...
# 1399  models_v6\alpha_0.75_epoch49_acc0.8730_prec0.1...
#
# [1400 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(data=model_sum_df, x='epoch', y='acc', hue='model_with_parameter')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
sns.lineplot(data=model_sum_df, x='epoch', y='precision', hue='model_with_parameter')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
sns.lineplot(data=model_sum_df, x='epoch', y='recall', hue='model_with_parameter')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
model_converged = model_sum_df[model_sum_df['epoch']>30]
model_converged
# Out:
#                                              model_name  \
# 31            model_training-v1_norestart_noweightclamp
# 32            model_training-v1_norestart_noweightclamp
# 33            model_training-v1_norestart_noweightclamp
# 34            model_training-v1_norestart_noweightclamp
# 35            model_training-v1_norestart_noweightclamp
# ...                                                 ...
# 1395  model_training-v6_restart_thresholdsearch_foca...
# 1396  model_training-v6_restart_thresholdsearch_foca...
# 1397  model_training-v6_restart_thresholdsearch_foca...
# 1398  model_training-v6_restart_thresholdsearch_foca...
# 1399  model_training-v6_restart_thresholdsearch_foca...
#
#                                    model_with_parameter weight  epoch alpha  \
# 31    model_training-v1_norestart_noweightclamp_weig...    0.0     31  None
# 32    model_training-v1_norestart_noweightclamp_weig...    0.0     32  None
# 33    model_training-v1_norestart_noweightclamp_weig...    0.0     33  None
# 34    model_training-v1_norestart_noweightclamp_weig...    0.0     34  None
# 35    model_training-v1_norestart_noweightclamp_weig...    0.0     35  None
# ...                                                 ...    ...    ...   ...
# 1395  model_training-v6_restart_thresholdsearch_foca...   None     45  0.75
# 1396  model_training-v6_restart_thresholdsearch_foca...   None     46  0.75
# 1397  model_training-v6_restart_thresholdsearch_foca...   None     47  0.75
# 1398  model_training-v6_restart_thresholdsearch_foca...   None     48  0.75
# 1399  model_training-v6_restart_thresholdsearch_foca...   None     49  0.75
#
#            acc  precision    recall  \
# 31    0.929155   0.628967  0.197777
# 32    0.929021   0.626391  0.196623
# 33    0.929359   0.634924  0.197032
# 34    0.929158   0.626777  0.200549
# 35    0.929121   0.628538  0.197181
# ...        ...        ...       ...
# 1395  0.874173   0.164541  0.261330
# 1396  0.872900   0.164482  0.265458
# 1397  0.873962   0.164605  0.262311
# 1398  0.874147   0.164457  0.261036
# 1399  0.872953   0.164428  0.265296
#
#                                                    path
# 31    models_v1\weight_0_epoch31_acc0.9292_prec0.629...
# 32    models_v1\weight_0_epoch32_acc0.9290_prec0.626...
# 33    models_v1\weight_0_epoch33_acc0.9294_prec0.634...
# 34    models_v1\weight_0_epoch34_acc0.9292_prec0.626...
# 35    models_v1\weight_0_epoch35_acc0.9291_prec0.628...
# ...                                                 ...
# 1395  models_v6\alpha_0.75_epoch45_acc0.8742_prec0.1...
# 1396  models_v6\alpha_0.75_epoch46_acc0.8729_prec0.1...
# 1397  models_v6\alpha_0.75_epoch47_acc0.8740_prec0.1...
# 1398  models_v6\alpha_0.75_epoch48_acc0.8741_prec0.1...
# 1399  models_v6\alpha_0.75_epoch49_acc0.8730_prec0.1...
#
# [532 rows x 9 columns]

# %%
acc_summary = model_converged[['model_with_parameter','acc']].groupby('model_with_parameter').mean().sort_values('acc',ascending=False)
acc_summary
# Out:
#                                                          acc
# model_with_parameter
# model_training-v5_restart_focalloss_alpha_None      0.929878
# model_training-v3_restart_logitsclamp_weightcla...  0.929807
# model_training-v5_restart_focalloss_alpha_0.25      0.929706
# model_training-v2_restart_noweightclamp_weight_0    0.929515
# model_training-v5_restart_focalloss_alpha_0.5       0.929515
# model_training-v1_norestart_noweightclamp_weight_0  0.929032
# model_training-v5_restart_focalloss_alpha_0.75      0.899480
# model_training-v3_restart_logitsclamp_weightcla...  0.890546
# model_training-v3_restart_logitsclamp_weightcla...  0.888493
# model_training-v3_restart_logitsclamp_weightcla...  0.888436
# model_training-v3_restart_logitsclamp_weightcla...  0.888080
# model_training-v2_restart_noweightclamp_weight_...  0.887878
# model_training-v1_norestart_noweightclamp_weigh...  0.887735
# model_training-v6_restart_thresholdsearch_focal...  0.879414
# model_training-v4_restart_thresholdsearch_weight_0  0.878062
# model_training-v6_restart_thresholdsearch_focal...  0.877662
# model_training-v6_restart_thresholdsearch_focal...  0.876346
# model_training-v6_restart_thresholdsearch_focal...  0.872427
# model_training-v4_restart_thresholdsearch_weigh...  0.861146
# model_training-v4_restart_thresholdsearch_weigh...  0.859500
# model_training-v4_restart_thresholdsearch_weight_1  0.855198
# model_training-v4_restart_thresholdsearch_weigh...  0.854783
# model_training-v2_restart_noweightclamp_weight_0.5  0.822709
# model_training-v1_norestart_noweightclamp_weigh...  0.821951
# model_training-v1_norestart_noweightclamp_weigh...  0.773422
# model_training-v2_restart_noweightclamp_weight_...  0.766803
# model_training-v1_norestart_noweightclamp_weight_1  0.735994
# model_training-v2_restart_noweightclamp_weight_1    0.732935

# %%
precision_summary = model_converged[['model_with_parameter','acc','precision','recall']].groupby('model_with_parameter').mean().sort_values('precision',ascending=False)
precision_summary
# Out:
#                                                          acc  precision  \
# model_with_parameter
# model_training-v5_restart_focalloss_alpha_0.25      0.929706   0.774580
# model_training-v5_restart_focalloss_alpha_None      0.929878   0.649965
# model_training-v3_restart_logitsclamp_weightcla...  0.929807   0.645390
# model_training-v2_restart_noweightclamp_weight_0    0.929515   0.640290
# model_training-v5_restart_focalloss_alpha_0.5       0.929515   0.639325
# model_training-v1_norestart_noweightclamp_weight_0  0.929032   0.625693
# model_training-v5_restart_focalloss_alpha_0.75      0.899480   0.358673
# model_training-v3_restart_logitsclamp_weightcla...  0.890546   0.333157
# model_training-v3_restart_logitsclamp_weightcla...  0.888493   0.327772
# model_training-v3_restart_logitsclamp_weightcla...  0.888436   0.326627
# model_training-v3_restart_logitsclamp_weightcla...  0.888080   0.325793
# model_training-v2_restart_noweightclamp_weight_...  0.887878   0.313541
# model_training-v1_norestart_noweightclamp_weigh...  0.887735   0.312335
# model_training-v2_restart_noweightclamp_weight_0.5  0.822709   0.241173
# model_training-v1_norestart_noweightclamp_weigh...  0.821951   0.240649
# model_training-v1_norestart_noweightclamp_weigh...  0.773422   0.213386
# model_training-v2_restart_noweightclamp_weight_...  0.766803   0.209219
# model_training-v1_norestart_noweightclamp_weight_1  0.735994   0.196585
# model_training-v2_restart_noweightclamp_weight_1    0.732935   0.194846
# model_training-v6_restart_thresholdsearch_focal...  0.879414   0.169435
# model_training-v6_restart_thresholdsearch_focal...  0.877662   0.168441
# model_training-v4_restart_thresholdsearch_weigh...  0.859500   0.165975
# model_training-v6_restart_thresholdsearch_focal...  0.876346   0.165452
# model_training-v4_restart_thresholdsearch_weight_1  0.855198   0.164894
# model_training-v4_restart_thresholdsearch_weigh...  0.861146   0.164823
# model_training-v6_restart_thresholdsearch_focal...  0.872427   0.164547
# model_training-v4_restart_thresholdsearch_weight_0  0.878062   0.163478
# model_training-v4_restart_thresholdsearch_weigh...  0.854783   0.163387
#
#                                                       recall
# model_with_parameter
# model_training-v5_restart_focalloss_alpha_0.25      0.124500
# model_training-v5_restart_focalloss_alpha_None      0.196081
# model_training-v3_restart_logitsclamp_weightcla...  0.198803
# model_training-v2_restart_noweightclamp_weight_0    0.195923
# model_training-v5_restart_focalloss_alpha_0.5       0.196939
# model_training-v1_norestart_noweightclamp_weight_0  0.197894
# model_training-v5_restart_focalloss_alpha_0.75      0.384912
# model_training-v3_restart_logitsclamp_weightcla...  0.418486
# model_training-v3_restart_logitsclamp_weightcla...  0.424228
# model_training-v3_restart_logitsclamp_weightcla...  0.420629
# model_training-v3_restart_logitsclamp_weightcla...  0.422019
# model_training-v2_restart_noweightclamp_weight_...  0.381540
# model_training-v1_norestart_noweightclamp_weigh...  0.379426
# model_training-v2_restart_noweightclamp_weight_0.5  0.605042
# model_training-v1_norestart_noweightclamp_weigh...  0.607495
# model_training-v1_norestart_noweightclamp_weigh...  0.721585
# model_training-v2_restart_noweightclamp_weight_...  0.728064
# model_training-v1_norestart_noweightclamp_weight_1  0.785294
# model_training-v2_restart_noweightclamp_weight_1    0.786162
# model_training-v6_restart_thresholdsearch_focal...  0.246956
# model_training-v6_restart_thresholdsearch_focal...  0.250604
# model_training-v4_restart_thresholdsearch_weigh...  0.317994
# model_training-v6_restart_thresholdsearch_focal...  0.250707
# model_training-v4_restart_thresholdsearch_weight_1  0.328690
# model_training-v4_restart_thresholdsearch_weigh...  0.312155
# model_training-v6_restart_thresholdsearch_focal...  0.266814
# model_training-v4_restart_thresholdsearch_weight_0  0.241062
# model_training-v4_restart_thresholdsearch_weigh...  0.328288

# %%
max_precision_model = precision_summary['precision'].idxmax()
max_precision_model
# Out:
# 'model_training-v5_restart_focalloss_alpha_0.25'

# %%
recall_summary = precision_summary.sort_values('recall',ascending=False)
recall_summary
# Out:
#                                                          acc  precision  \
# model_with_parameter
# model_training-v2_restart_noweightclamp_weight_1    0.732935   0.194846
# model_training-v1_norestart_noweightclamp_weight_1  0.735994   0.196585
# model_training-v2_restart_noweightclamp_weight_...  0.766803   0.209219
# model_training-v1_norestart_noweightclamp_weigh...  0.773422   0.213386
# model_training-v1_norestart_noweightclamp_weigh...  0.821951   0.240649
# model_training-v2_restart_noweightclamp_weight_0.5  0.822709   0.241173
# model_training-v3_restart_logitsclamp_weightcla...  0.888493   0.327772
# model_training-v3_restart_logitsclamp_weightcla...  0.888080   0.325793
# model_training-v3_restart_logitsclamp_weightcla...  0.888436   0.326627
# model_training-v3_restart_logitsclamp_weightcla...  0.890546   0.333157
# model_training-v5_restart_focalloss_alpha_0.75      0.899480   0.358673
# model_training-v2_restart_noweightclamp_weight_...  0.887878   0.313541
# model_training-v1_norestart_noweightclamp_weigh...  0.887735   0.312335
# model_training-v4_restart_thresholdsearch_weight_1  0.855198   0.164894
# model_training-v4_restart_thresholdsearch_weigh...  0.854783   0.163387
# model_training-v4_restart_thresholdsearch_weigh...  0.859500   0.165975
# model_training-v4_restart_thresholdsearch_weigh...  0.861146   0.164823
# model_training-v6_restart_thresholdsearch_focal...  0.872427   0.164547
# model_training-v6_restart_thresholdsearch_focal...  0.876346   0.165452
# model_training-v6_restart_thresholdsearch_focal...  0.877662   0.168441
# model_training-v6_restart_thresholdsearch_focal...  0.879414   0.169435
# model_training-v4_restart_thresholdsearch_weight_0  0.878062   0.163478
# model_training-v3_restart_logitsclamp_weightcla...  0.929807   0.645390
# model_training-v1_norestart_noweightclamp_weight_0  0.929032   0.625693
# model_training-v5_restart_focalloss_alpha_0.5       0.929515   0.639325
# model_training-v5_restart_focalloss_alpha_None      0.929878   0.649965
# model_training-v2_restart_noweightclamp_weight_0    0.929515   0.640290
# model_training-v5_restart_focalloss_alpha_0.25      0.929706   0.774580
#
#                                                       recall
# model_with_parameter
# model_training-v2_restart_noweightclamp_weight_1    0.786162
# model_training-v1_norestart_noweightclamp_weight_1  0.785294
# model_training-v2_restart_noweightclamp_weight_...  0.728064
# model_training-v1_norestart_noweightclamp_weigh...  0.721585
# model_training-v1_norestart_noweightclamp_weigh...  0.607495
# model_training-v2_restart_noweightclamp_weight_0.5  0.605042
# model_training-v3_restart_logitsclamp_weightcla...  0.424228
# model_training-v3_restart_logitsclamp_weightcla...  0.422019
# model_training-v3_restart_logitsclamp_weightcla...  0.420629
# model_training-v3_restart_logitsclamp_weightcla...  0.418486
# model_training-v5_restart_focalloss_alpha_0.75      0.384912
# model_training-v2_restart_noweightclamp_weight_...  0.381540
# model_training-v1_norestart_noweightclamp_weigh...  0.379426
# model_training-v4_restart_thresholdsearch_weight_1  0.328690
# model_training-v4_restart_thresholdsearch_weigh...  0.328288
# model_training-v4_restart_thresholdsearch_weigh...  0.317994
# model_training-v4_restart_thresholdsearch_weigh...  0.312155
# model_training-v6_restart_thresholdsearch_focal...  0.266814
# model_training-v6_restart_thresholdsearch_focal...  0.250707
# model_training-v6_restart_thresholdsearch_focal...  0.250604
# model_training-v6_restart_thresholdsearch_focal...  0.246956
# model_training-v4_restart_thresholdsearch_weight_0  0.241062
# model_training-v3_restart_logitsclamp_weightcla...  0.198803
# model_training-v1_norestart_noweightclamp_weight_0  0.197894
# model_training-v5_restart_focalloss_alpha_0.5       0.196939
# model_training-v5_restart_focalloss_alpha_None      0.196081
# model_training-v2_restart_noweightclamp_weight_0    0.195923
# model_training-v5_restart_focalloss_alpha_0.25      0.124500

# %%
max_recall_model = recall_summary['recall'].idxmax()
max_recall_model
# Out:
# 'model_training-v2_restart_noweightclamp_weight_1'

# %%
print('best model for precision:', max_precision_model, 'with precision of', precision_summary.loc[max_precision_model]['precision'], ', recall: ' ,  recall_summary.loc[max_precision_model]['recall'], ', acc: ', acc_summary.loc[max_precision_model]['acc']),print('best model for recall:', max_recall_model, 'with recall of', recall_summary.loc[max_recall_model]['recall'], 'precision: ', precision_summary.loc[max_recall_model]['precision'], ', acc: ', acc_summary.loc[max_recall_model]['acc'])
# Out:
# best model for precision: model_training-v5_restart_focalloss_alpha_0.25 with precision of 0.7745801672963919 , recall:  0.1245003997449544 , acc:  0.9297062894653365
# best model for recall: model_training-v2_restart_noweightclamp_weight_1 with recall of 0.7861619724399148 precision:  0.19484633482707933 , acc:  0.7329347001039579
# (None, None)

# %%
plt.plot(precision_summary.index, precision_summary[['precision','recall','acc']], label=['precision','recall','acc'])
plt.xticks(ticks= [i for i in range(len(precision_summary.index))],labels = [i for i in range(len(precision_summary.index))])
plt.legend()
plt.show()

# %%
# coppy the best model to current directory for easy access
import shutil
best_precision_model = model_converged[model_converged['model_with_parameter'] == max_precision_model].sort_values('precision', ascending=False).iloc[0]
shutil.copyfile(os.path.join(current_dir, best_precision_model['path']), os.path.join(current_dir, 'best_model', 'best_precision_model'+best_precision_model['model_with_parameter']+'_'+str(best_precision_model['epoch'])+'.pth'))
best_recall_model = model_converged[model_converged['model_with_parameter'] == max_recall_model].sort_values('recall', ascending=False).iloc[0]
shutil.copyfile(os.path.join(current_dir, best_recall_model['path']), os.path.join(current_dir, 'best_model','best_recall_model_'+best_recall_model['model_with_parameter']+'_'+str(best_recall_model['epoch'])+'.pth'))
# Out:
# 'c:\\Users\\yeech\\Documents\\Project\\elevator-tcn\\best_model\\best_recall_model_model_training-v2_restart_noweightclamp_weight_1_36.pth'

# %%
model_sum_df.to_csv(os.path.join(current_dir, 'model_summary.csv'), index=False)
