# %%
import os
import pandas as pd

# %%
cur_dir =os.getcwd()
model_dfs = []
for file in os.listdir(cur_dir):
    if file.endswith('.pth'):
        model_name = file.replace('.pth','')
        _, alpha, epochs, acc, prec, recall = model_name.split('_')
        model_dfs.append({
            'Model': model_name+'.pth',
            'alpha': float(alpha),
            'epoch': int(epochs.replace('epoch', '')),
            'acc': float(acc.replace('acc', '')),
            'precision': float(prec.replace('prec', '')),
            'recall': float(recall.replace('rec', ''))
        })
model_dfs = pd.DataFrame(model_dfs)
model_dfs
# Out:
#                                                 Model  alpha  epoch     acc  \
# 0   alpha_0.25_epoch00_acc0.9580_prec0.6600_rec0.0...   0.25      0  0.9580
# 1   alpha_0.25_epoch00_acc0.9580_prec0.6618_rec0.0...   0.25      0  0.9580
# 2   alpha_0.25_epoch01_acc0.9578_prec0.6657_rec0.0...   0.25      1  0.9578
# 3   alpha_0.25_epoch01_acc0.9578_prec0.6675_rec0.0...   0.25      1  0.9578
# 4   alpha_0.25_epoch02_acc0.9578_prec0.6679_rec0.0...   0.25      2  0.9578
# 5   alpha_0.25_epoch02_acc0.9578_prec0.6749_rec0.0...   0.25      2  0.9578
# 6   alpha_0.25_epoch03_acc0.9577_prec0.6675_rec0.0...   0.25      3  0.9577
# 7   alpha_0.25_epoch04_acc0.9578_prec0.6733_rec0.0...   0.25      4  0.9578
# 8   alpha_0.25_epoch05_acc0.9578_prec0.6728_rec0.0...   0.25      5  0.9578
# 9   alpha_0.25_epoch06_acc0.9578_prec0.6704_rec0.0...   0.25      6  0.9578
# 10  alpha_0.25_epoch07_acc0.9578_prec0.6744_rec0.0...   0.25      7  0.9578
# 11  alpha_0.25_epoch08_acc0.9578_prec0.6773_rec0.0...   0.25      8  0.9578
# 12  alpha_0.25_epoch09_acc0.9578_prec0.6739_rec0.0...   0.25      9  0.9578
# 13  alpha_0.25_epoch10_acc0.9578_prec0.6735_rec0.0...   0.25     10  0.9578
# 14  alpha_0.25_epoch11_acc0.9578_prec0.6734_rec0.0...   0.25     11  0.9578
# 15  alpha_0.25_epoch12_acc0.9578_prec0.6744_rec0.0...   0.25     12  0.9578
# 16  alpha_0.25_epoch13_acc0.9578_prec0.6734_rec0.0...   0.25     13  0.9578
# 17  alpha_0.25_epoch14_acc0.9578_prec0.6707_rec0.0...   0.25     14  0.9578
# 18  alpha_0.25_epoch15_acc0.9578_prec0.6708_rec0.0...   0.25     15  0.9578
# 19  alpha_0.25_epoch16_acc0.9578_prec0.6697_rec0.0...   0.25     16  0.9578
# 20  alpha_0.25_epoch17_acc0.9578_prec0.6728_rec0.0...   0.25     17  0.9578
# 21  alpha_0.25_epoch18_acc0.9578_prec0.6715_rec0.0...   0.25     18  0.9578
# 22  alpha_0.25_epoch19_acc0.9578_prec0.6713_rec0.0...   0.25     19  0.9578
# 23  alpha_0.75_epoch00_acc0.9478_prec0.3841_rec0.3...   0.75      0  0.9478
# 24  alpha_0.75_epoch01_acc0.9497_prec0.4012_rec0.3...   0.75      1  0.9497
# 25  alpha_0.75_epoch02_acc0.9503_prec0.4070_rec0.3...   0.75      2  0.9503
# 26  alpha_0.75_epoch03_acc0.9506_prec0.4101_rec0.3...   0.75      3  0.9506
# 27  alpha_0.75_epoch04_acc0.9512_prec0.4154_rec0.3...   0.75      4  0.9512
# 28  alpha_0.75_epoch05_acc0.9511_prec0.4146_rec0.3...   0.75      5  0.9511
# 29  alpha_0.75_epoch06_acc0.9512_prec0.4165_rec0.3...   0.75      6  0.9512
# 30  alpha_0.75_epoch07_acc0.9516_prec0.4197_rec0.3...   0.75      7  0.9516
# 31  alpha_0.75_epoch08_acc0.9516_prec0.4203_rec0.3...   0.75      8  0.9516
# 32  alpha_0.75_epoch09_acc0.9517_prec0.4214_rec0.3...   0.75      9  0.9517
# 33  alpha_0.75_epoch10_acc0.9520_prec0.4238_rec0.3...   0.75     10  0.9520
# 34  alpha_0.75_epoch11_acc0.9520_prec0.4239_rec0.3...   0.75     11  0.9520
# 35  alpha_0.75_epoch12_acc0.9519_prec0.4234_rec0.3...   0.75     12  0.9519
# 36  alpha_0.75_epoch13_acc0.9522_prec0.4266_rec0.3...   0.75     13  0.9522
# 37  alpha_0.75_epoch14_acc0.9522_prec0.4259_rec0.3...   0.75     14  0.9522
# 38  alpha_0.75_epoch15_acc0.9520_prec0.4238_rec0.3...   0.75     15  0.9520
# 39  alpha_0.75_epoch16_acc0.9521_prec0.4256_rec0.3...   0.75     16  0.9521
# 40  alpha_0.75_epoch17_acc0.9522_prec0.4265_rec0.3...   0.75     17  0.9522
# 41  alpha_0.75_epoch18_acc0.9522_prec0.4265_rec0.3...   0.75     18  0.9522
# 42  alpha_0.75_epoch19_acc0.9523_prec0.4270_rec0.3...   0.75     19  0.9523
#
#     precision  recall
# 0      0.6600  0.0293
# 1      0.6618  0.0297
# 2      0.6657  0.0193
# 3      0.6675  0.0200
# 4      0.6679  0.0172
# 5      0.6749  0.0204
# 6      0.6675  0.0160
# 7      0.6733  0.0178
# 8      0.6728  0.0173
# 9      0.6704  0.0165
# 10     0.6744  0.0181
# 11     0.6773  0.0201
# 12     0.6739  0.0180
# 13     0.6735  0.0178
# 14     0.6734  0.0174
# 15     0.6744  0.0187
# 16     0.6734  0.0179
# 17     0.6707  0.0175
# 18     0.6708  0.0186
# 19     0.6697  0.0169
# 20     0.6728  0.0194
# 21     0.6715  0.0187
# 22     0.6713  0.0186
# 23     0.3841  0.3728
# 24     0.4012  0.3652
# 25     0.4070  0.3632
# 26     0.4101  0.3625
# 27     0.4154  0.3592
# 28     0.4146  0.3607
# 29     0.4165  0.3600
# 30     0.4197  0.3574
# 31     0.4203  0.3575
# 32     0.4214  0.3565
# 33     0.4238  0.3546
# 34     0.4239  0.3544
# 35     0.4234  0.3548
# 36     0.4266  0.3521
# 37     0.4259  0.3529
# 38     0.4238  0.3543
# 39     0.4256  0.3527
# 40     0.4265  0.3521
# 41     0.4265  0.3521
# 42     0.4270  0.3516

# %%
model_dfs.to_csv('model_df.csv', index=False)
